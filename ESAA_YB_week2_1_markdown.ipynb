# %% [markdown]
# <a href="https://colab.research.google.com/github/yoooobin/ESAA/blob/main/ESAA_YB_week2_1_markdown.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##10 _ 시각화

# %% [markdown]
# ####01 시각화를 시작하며 - 맷플롯립과 시본 개요

# %% [markdown]
# *   파이썬 기반 시각화 대표적인 라이브러리: 맷플롯립(Matplotlib), 시본(Serborn)

# %% [markdown]
# ####02 맷플롯립(Matplotlib)

# %% [markdown]
# **[맷플롯립의 pyplot 모듈의 이해]**

# %% [markdown]
# *   맷플롯립: 파이썬 시각화를 위한 기반 모듈인 pyplot을 기반으로 시각화를 구현
# *   plot( ) 함수를 통해 선 그래프를 그림
# *   title( ) 함수로 입력값으로 타이틀 문자열을 받아서 차트 타이틀을 설정
# *   show( ) 함수를 호출하여 축을 포함한 선 그래프를 화면에 나타냄

# %%
# pyplot 모듈을 (관용적으로) plt라는 이름으로 import.
import matplotlib.pyplot as plt

# x축 입력값 [1, 2, 3], y축 입력값 [2, 4, 6]으로 선 그래프 생성.
plt.plot([1, 2, 3], [2, 4, 6])

# 선그래프 타이틀을 Hello plot으로 설정.
plt.title("Hello plot")

# 선 그래프를 출력
plt.show()

# %% [markdown]
# *   MATLAB에서 시각화를 위해 개발한 라이브러리에서 유래

# %% [markdown]
# **[pyplot의 두 가지 중요 요소 - Figure와 Axes 이해]**

# %% [markdown]
# *   Figure 객체: 그림을 그리기 위한 캔버스의 역할 / 하지만 실제적으로 그림을 그리는 역할을 수행하지 않음
# *   Axes 객체: 실제 그림을 그리는 메서드(시각화와 관련된 많은 작업들이 Axes 객체 기반에서 수행)
# *   1_ plt.plot([1, 2, 3], [2, 4, 6]) 기본으로 설정된 Axes에서 Axes.plot( ) 함수를 포출하여 그림을 그리고 다시 Line2D 객체를 호출하여 선 그래프를 그림
# *   2_ plt.title("Hello plot") 내부적으로 다시 Axes.set_title( ) 함수를 호출하여 타이틀을 설정

# %%
# plt.figure()는 주로 figure의 크기를 조절하는 데 사용됨.
# 아래는 figure 크기가 가로 10, 세로 4인 Figure 객체를 설정하고 반환함,
plt.figure(figsize=(10, 4))

plt.plot([1, 2, 3], [2, 4, 6])
plt.title("Hello plot")
plt.show()

# %%
figure = plt.figure(figsize=(10, 4))
print(type(figure))
# Out:
# <class 'matplotlib.figure.Figure'>

# %% [markdown]
# *   plt.figure( ) 함수에 의해 반환된 Figure가 실제로 그림을 그리지는 못하지만 그림판의 배경 색깔을 바꾸는 등의 설정 가능

# %%
plt.figure(figsize=(4, 4), facecolor='yellow')
plt.plot([1, 2, 3], [2, 4, 6])
plt.title("Hello plot")
plt.show()

# %% [markdown]
# *   plt의 axes( ) 함수: 현재 사용하는 Axes 객체 반환

# %%
ax = plt.axes( )
print(type(ax))
# Out:
# <class 'matplotlib.axes._axes.Axes'>

# %% [markdown]
# *   plt.axes( )로 반환된 객체 AxesSubplot는 Axes의 실체화된 하위 클래스
# *   plt.subplots( ): pyplot에서 Figure와 Axes 객체 함께 가져올 수 있음

# %%
### pyplot에서 설정된 Figure와 Axes 객체를 함께 가져오기
fig, ax = plt.subplots()
print('fig type:', type(fig), '\nax type:', type(ax))
# Out:
# fig type: <class 'matplotlib.figure.Figure'>
# ax type: <class 'matplotlib.axes._axes.Axes'>

# %%
fig, ax = plt.subplots(figsize=(4,4))

# Axes 객체의 plot()을 이용하여 선 그래프를 그림.
ax.plot([1, 2, 3], [2, 4, 6])

# Axes 객체의 set_title( )을 이용하여 선 그래프 타이틀을 Hello plot으로 설정.
ax.set_title('Hello plot')
plt.show()

# %% [markdown]
# **[여러 개의 plot을 가지는 subplot들을 생성하기]**

# %% [markdown]
# *   plt.subplots( ) 함수는 주로 여러 개의 subplot을 생성하는 데 활용
# *   하나의 Figure상에서 여러 개의 그래프를 그릴 수 있도록 하고 개별 subplot은 하나의 Axes를 가짐
# *   주요 인자: nrows, ncols, figsize

# %%
# 아래는 두 개의 subplot, 즉 두 개의 Axes를 생성하되 열 방향으로 두 개를 배치함.
# 또한 전체 크기가 가로 6, 세로 3인 Figure 생성.
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(6, 3))

# %% [markdown]
# **[여러 개의 plot을 가지는 subplot들을 생성하기]**

# %% [markdown]
# plt.subplots( ) 함수: 주로 여러 개의 subplot 생성하는 데 활용

# %%
# 아래는 두 개의 subplot, 즉 두 개의 Axes를 생성하되 열 방향으로 두 개를 배치함.
# 또한 전체 크기가 가로 6, 세로 3인 Figure 생성.
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(6, 3))

# %% [markdown]
# **[pyplot의 plot() 함수를 이용해 선 그리기]**

# %% [markdown]
# *   pyplot의 plot( ) 함수는 선 그래프를 그릴 때 활용

# %%
import numpy as np
import pandas as pd


x_value = [1, 2, 3, 4]
y_value = [2, 4, 6, 8]
#x_value = np.array([1, 2, 3, 4])  # 넘파이 array로 테스트하려면 주석을 해제하고 실행
#y_value = np.array([2, 4, 6, 8])  # 넘파이 array로 테스트하려면 주석을 해제하고 실행


# 입력값으로 파이썬 리스트, numpy array 가능, x 좌표값과 y좌표값은 모두 같은 크기를 가져야 함.
plt.plot(x_value, y_value)
plt.show()

# %% [markdown]
# *   plot( ) 함수로 color 인자를 이용해 선의 색깔 변경

# %%
# color 인자를 green으로 설정하여 선의 색깔을 녹색으로 변경.
plt.plot(x_value, y_value, color='green')

# %%
# API 기반으로 시각화를 구현할 때는 함수의 인자들에 대해서 알고 있어야 하는 부작용(?)이 있음.
plt.plot(
    x_value, y_value, color='red', marker='o', linestyle='dashed', linewidth=2, markersize=12
)

# %% [markdown]
# *   API 기반 시각화: 코드를 이용해 해당 함수들에 대한 인자 값이나 시각화를 위한 여러 주변 값들을 설정해줘야 함
# *   X축, Y축 명칭을 설정하거나 범례를 설정하는 작업을 별도의 함수들을 사용해서 구현 / 데이터 분석에서 사용되는 여러 차트 만들때 여러 함수 조합해서 만들수도 있음

# %% [markdown]
# **[축 명칭 설정, 축의 눈금(틱)값 회전, 범례(legend) 설정하기]**

# %% [markdown]
# *   pyplot의 xlabel( ), ylabel( ) 같은 함수로 축의 명칭 설정

# %%
plt.plot(
    x_value, y_value, color='red', marker='o',linestyle='dashed', linewidth=2, markersize=12
)

# x축과 y축의 이름을 텍스트로 할당하여 설정.
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %% [markdown]
# *   X축의 눈금값 회전: xticks()
# *   Y축의 눈금값 회전: yticks() (보통 X축만 눈금값을 회전)

# %%
# x 좌표 값을 0~99까지 100개로 설정.
x_value = np.arange(0, 100)
# y 좌표 값은 개별 x좌표값을 2배로 해서 100개로 설정.
y_value = 2*x_value

plt.plot(x_value, y_value, color='green')
plt.xlabel('x axis')
plt.ylabel('y axis')

# x축 눈금값을 90도로 회전
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# *   맷플롯립의 축 값이 문자열인 경우 모든 값을 나타내주지만 축 값이 숫자값이면 자동으로 최솟값과 최댓값에 기반해 축의 크기에 따라 눈금 간격을 생성

# %%
x_value = np.arange(0, 100)
y_value = 2*x_value

plt.plot(x_value, y_value, color='green')
plt.xlabel('x axis')
plt.ylabel('y axis')

# X축의 눈금값을 np.arange(0, 100, 5)로 하여 0부터 99까지 5 스텝으로 20개를 표시하고
# 90도 회전
plt.xticks(ticks=np.arange(0, 100, 5), rotation=90)

plt.title('Hello plot')
plt.show()

# %% [markdown]
# *   범례(legend): 여러 개의 그래프/차트를 한 Axes 내에서 표시할 때 구분할 때 편리하게 사용
# *   plt.legend( ): 범례를 Axes상에서 나타낼 수 있음

# %%
# X좌표값은 0~99까지 100개, 첫번째 Y좌표값은 X좌표값의 두 배, 두번째 좌표값은
# X좌표값의 4배
x_value_01 = np.arange(0, 100)
y_value_01 = 2*x_value_01
y_value_02 = 4*x_value_01

# X좌표값과 첫번째 Y좌표값으로 녹색의 선그래프 그림. label을 'green line'으로 설정.
plt.plot(x_value_01, y_value_01, color='green', label='green line')
# X좌표값과 두번째 Y좌표값으로 빨간색 선그래프를 그림. label을 'red line'으로 설정.
plt.plot(x_value_01, y_value_02, color='red', label='red line')

plt.xlabel('x axis')
plt.ylabel('y axis')
# 개별 plot들의 label로 설정된 문자열을 범례로 표시
plt.legend()

plt.title('Hello plot')

plt.show()

# %%
x_value_01 = np.arange(1, 10)
y_value_01 = 2*x_value_01

# 마커를 포함한 빨간색 대시 선 그래프를 그리고, label은 'red line'으로 설정
plt.plot(x_value_01, y_value_01, color='red', marker='o', linestyle='dashed', label='red line')
# X값에 따른 Y값을 나타내는 초록색 막대 그래프를 그리고 label은 'bar plot'으로 설정
plt.bar(x_value_01, y_value_01, color='green', label='bar plot')
plt.xlabel('x axis')
plt.ylabel('y axis')
# 두 개의 그래프에서 label로 설정된 문자열을 범례로 표시
plt.legend()

plt.title('Hello plot')

plt.show()

# %%
figure = plt.figure()
# Axes 객체를 추출하여 ax 변수에 할당.
ax = plt.axes()

# plt.plot( )은 ax.plot( )으로 plt.bar( )는 ax.bar( )로 변경.
ax.plot(x_value_01, y_value_01, color='red', marker='o', linestyle='dashed', label='red line')
ax.bar(x_value_01, y_value_01, color='green', label='bar plot')

# plt.xlabel( )은 ax.set_xlabel( )로, plt.ylabel( )은 ax.set_ylabel( )로 변경
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')

# ax.set_legend( )가 아니라 ax.legend( )임.
ax.legend()
# plt.title( )을 plt.set_title( )로 변경
ax.set_title('Hello plot')

plt.show()

# %% [markdown]
# **[여러 개의 subplots들을 이용해 개별 그래프들을 subplot별로 시각화하기]**

# %% [markdown]
# *   많은 피처들로 이뤄진 데이터 세트를 분석할 때 서로 다른 피처 간의 그래프 비교
# *   같은 피처라도 서로 다른 그래프를 이용해 여러 가지 특성들을 한눈에 분석

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(6, 3))

# %% [markdown]
# *    반환된 Axes 객체들을 가지는 ax 변수는 튜플이 아니라 넘파이 ndarray 형태

# %%
print('ax type:', type(ax))
print('ax[0] type:', type(ax[0]))
print('ax[1] type:', type(ax[1]))
# Out:
# ax type: <class 'numpy.ndarray'>
# ax[0] type: <class 'matplotlib.axes._axes.Axes'>
# ax[1] type: <class 'matplotlib.axes._axes.Axes'>

# %% [markdown]
# *   여러 개의 subplots들을 이용해 시각화를 구현할 때 개별 Axes 객체를 직접 이용해서 시각화를 구현해야 함
# *   선 그래프, 막대 그래프, 타이틀, 축 명칭 눈금값, 범례 등에도 직접 적용

# %%
import numpy as np

x_value_01 = np.arange(1, 10)
x_value_02 = np.arange(1, 20)
y_value_01 = 2 * x_value_01
y_value_02 = 2 * x_value_02

# figsize는 (6,3)인 Figure와 2개의 Axes를 가지는 subplots을 반환.
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(6, 3))

# 개별 Axes 객체들을 각각 이용하여 선 그래프와 막대그래프를 그림.
ax[0].plot(x_value_01, y_value_01, color='red', marker='o', linestyle='dashed', label='red line')
ax[1].bar(x_value_02, y_value_02, color='green', label='bar plot')
# 개별 Axes 객체 각각에 X축명을 설정.
ax[0].set_xlabel('ax[0] x axis')
ax[1].set_xlabel('ax[1] x axis')
# 개별 Axes 객체 각각에 범례를 설정
ax[0].legend()
ax[1].legend()
# 개별 Axes 객체 각각에 타이틀을 설정
ax[0].set_title('Hello line')
ax[1].set_title('Hello bar')

plt.show()

# %%
import numpy as np

x_value_01 = np.arange(1, 10)
x_value_02 = np.arange(1, 20)
y_value_01 = 2 * x_value_01
y_value_02 = 2 * x_value_02

# figsize는 (6,6)인 Figure와 2x2개의 Axes를 가지는 subplots을 반환.
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(6,6))

# 2x2 Axes 객체들을 각각 이용하여 선 그래프와 막대그래프를 그림.
ax[0][0].plot(x_value_01, y_value_01, color='red', marker='o', linestyle='dashed', label='red line')
ax[0][1].bar(x_value_02, y_value_02, color='green', label='green bar')
ax[1][0].plot(
    x_value_01, y_value_01, color='green', marker='o', linestyle='dashed', label='green line'
)
ax[1][1].bar(x_value_02, y_value_02, color='red', label='red bar')

# 개별 Axes 객체 각각에 X축명을 설정.
ax[0][0].set_xlabel('ax[0][0] x axis')
ax[0][1].set_xlabel('ax[0][1] x axis')
ax[1][0].set_xlabel('ax[1][0] x axis')
ax[1][1].set_xlabel('ax[1][1] x axis')

# 개별 Axes 객체 각각에 범례를 설정
ax[0][0].legend()
ax[0][1].legend()
ax[1][0].legend()
ax[1][1].legend()

plt.show()
