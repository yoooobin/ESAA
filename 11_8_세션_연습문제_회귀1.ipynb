# %% [markdown]
# <a href="https://colab.research.google.com/github/yoooobin/ESAA/blob/main/11_8_%EC%84%B8%EC%85%98_%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C_%ED%9A%8C%EA%B7%801.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. 단순 선형 회귀 분석**
# - 전복의 나이를 예측하는 선형회귀모델을 생성하세요.
# - 전복의 ‘성별’, ‘키’, ‘지름’, ‘높이’, ‘전체무게’, ‘몸통무게’, ‘내장무게’, ‘껍질무게’를 이용해 ‘껍질의 고리 수’를 예측한 뒤, **예측된 ‘껍질의 고리 수’에 1.5를 더하면 전복의 나이**가 됩니다.

# %%
# 기본 모듈 불러오기
import numpy as np
import pandas as pd

# %% [markdown]
# **1) 데이터 load 및 변형**

# %%
# 데이터 로드
data = pd.read_csv("abalone.csv")
data.head()
print(data.shape)

# 성별 M은 Male, F는 Female, I는 Infant 이므로 따로 열 만들기
for label in "MFI":
    data[label] = data["Sex"] == label
data.drop('Sex', axis=1, inplace=True)
# Out:
# (4177, 9)

# %% [markdown]
# **2) X, y 선택**
# : y는 Rings열, X는 Rings열을 제외한 나머지를 선택하되 전부 실수가 되도록 한다.

# %%
# X,y 데이터 선택
y = data['Rings']
X = data.drop('Rings', axis=1).astype('float')

# %% [markdown]
#  **3) train/test set 분리**

# %%
# 필요한 모듈 불러오기
from sklearn.model_selection import train_test_split

# %%
# train과 test set 분리 (train:test = 7:3 비율로)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# **4) 선형회귀모델 생성, 모델 예측치 구하기**

# %%
#필요한 모듈 불러오기
from sklearn.linear_model import LinearRegression

# %%
#선형회귀모델 생성 및 훈련
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 모델 예측치 구하기
y_preds = lr.predict(X_test)

# 모델 예측치를 활용해 최종적으로 전복의 나이를 예측
age_preds = y_preds + 1.5

age_preds
# Out:
# array([10.3515625,  9.796875 , 11.9765625, ...,  6.90625  , 11.265625 ,
#        11.0234375])

# %% [markdown]
# **5) 모델 평가: MSE, RMSE, R2 score, corr 구하기**

# %%
#필요한 모듈 불러오기
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# - MSE, RMSE

# %%
#mse, rmse
mse = mean_squared_error(y_test, y_preds)
rmse = np.sqrt(mse)

print(mse, rmse)
# Out:
# 4.864472165632476 2.2055548430343954

# %% [markdown]
# - R2 score

# %%
#R2 score 측정
r2 = r2_score(y_test, y_preds)
r2
# Out:
# 0.5076151998124738

# %% [markdown]
# - 회귀 절편값

# %%
#회귀 절편 값
lr.intercept_
# Out:
# 48916181239229.69

# %% [markdown]
# - 회귀 계수 값

# %%
#회귀 계수 값
lr.coef_
# Out:
# array([-1.43613356e+00,  1.23583832e+01,  8.50548508e+00,  1.03235647e+01,
#        -2.14550166e+01, -1.09909053e+01,  7.34817245e+00, -4.89161812e+13,
#        -4.89161812e+13, -4.89161812e+13])

# %% [markdown]
# - 상관계수
#
# Hint: corr 함수 이용.

# %%
# 상관계수 구하기
df = pd.DataFrame({'y_test':y_test, 'y_pred':y_preds})
df.corr()
# Out:
#           y_test    y_pred
# y_test  1.000000  0.713655
# y_pred  0.713655  1.000000

# %% [markdown]
# # **2. Polynomial features**

# %%
# PolynomialFeatures 라이브러리 호출
from sklearn.preprocessing import PolynomialFeatures

# %%
# 임의 데이터 생성

X = np.arange(6).reshape(3, 2)

df =  pd.DataFrame(X)
df.columns = ['x_1','x_2']
df
# Out:
#    x_1  x_2
# 0    0    1
# 1    2    3
# 2    4    5

# %%
# 차원은 2로 설정
# fit_transform 메소드를 통해 데이터 변환
# PolynomialFeatures로 변환 된 데이터를 데이터 프레임 형태로 변환
poly = PolynomialFeatures(degree=2)
poly_ftr = poly.fit_transform(df)
df_poly = pd.DataFrame(poly_ftr)
df_poly
# Out:
#      0    1    2     3     4     5
# 0  1.0  0.0  1.0   0.0   0.0   1.0
# 1  1.0  2.0  3.0   4.0   6.0   9.0
# 2  1.0  4.0  5.0  16.0  20.0  25.0

# %%
# df_poly의 컬럼을 1,x1,x2,x1^2,x1*x2,x2^2 로 변경
df_poly = pd.DataFrame(poly_ftr, columns=['1', 'x1', 'x2', 'x1^2', 'x1*x2', 'x2^2'])
df_poly
# Out:
#      1   x1   x2  x1^2  x1*x2  x2^2
# 0  1.0  0.0  1.0   0.0    0.0   1.0
# 1  1.0  2.0  3.0   4.0    6.0   9.0
# 2  1.0  4.0  5.0  16.0   20.0  25.0
